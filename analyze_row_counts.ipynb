# %% [markdown]
# # Excel Row Count Comparison Analysis
#
# This notebook analyzes the Excel file to compare SLTLoadedRowCount and NewLakeLoadedRowCount values across all sheets.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
import multiprocessing as mp
from functools import partial
import time

warnings.filterwarnings("ignore")

# Set up file path
excel_file = "./output/output_csvs.xlsx"
print(f"Analyzing file: {excel_file}")

# Set up multiprocessing
num_processes = min(mp.cpu_count(), 8)  # Use up to 8 cores, but not more than available
print(f"Using {num_processes} processes for parallel analysis")
# Out:
# Analyzing file: ./output/output_csvs.xlsx
# Using 8 processes for parallel analysis

# %%
# Read the Excel file and get all sheet names
try:
    excel_file_obj = pd.ExcelFile(excel_file)
    sheet_names = excel_file_obj.sheet_names
    print(f"Found {len(sheet_names)} sheets: {sheet_names}")
except Exception as e:
    print(f"Error reading Excel file: {e}")
    sheet_names = []
# Out:
# Found 969 sheets: ['a016', 'a068', 'a551', 'a594', 'a651', 'a652', 'a653', 'a654', 'a655', 'a656', 'a717', 'a733', 'a734', 'a735', 'a736', 'a737', 'a738', 'a748', 'a749', 'a753', 'a757', 'a762', 'acdoca', 'acdoca_m_extract', 'acdocp', 'adr12', 'adr2', 'adr3', 'adr6', 'adrc', 'adrct', 'adrp', 'adrt', 'afih', 'afko', 'afpo', 'afru', 'afvc', 'afvu', 'afvv', 'agr_1251', 'agr_tcodes', 'agr_users', 'anka', 'ankb', 'ankt', 'anla', 'anlb', 'anlc', 'anlh', 'anli', 'anlz', 'auak', 'auas', 'aufk', 'aufm', 'ausp', 'bic_azco_d0021', 'bic_azco_d0022', 'bic_azpf_d0011', 'bic_azpf_d0012', 'bic_azpf_d0052', 'bic_hzglaccnt', 'bic_pzconsview', 'bic_pzdatasrc', 'bic_pzversion', 'bic_szflow', 'bic_tzconsview', 'bic_tzdatasrc', 'bic_tzpyear', 'bic_tzversion', 'bkpf', 'bp1010', 'bseg', 'bset', 'but000', 'but050', 'c001', 'c002', 'c003', 'c004', 'c005', 'c501', 'cabn', 'cabnt', 'cawn', 'cawnt', 'cdhdr', 'cdpos', 'ce9tysn_h', 'ce9tysn_ic', 'ce9tysn_iq', 'ce9tysn_iv', 'cepc', 'cepct', 'ckis', 'ckmlcr', 'ckmlhd', 'ckmlkont', 'ckmllahd', 'ckmlmv001', 'ckmlmv003', 'ckmlmv006', 'ckmlmv006t', 'ckmlmv009', 'ckmlmv009t', 'cobk', 'coepr', 'cokey', 'cooi', 'cosl', 'cosp_bak', 'cosr', 'coss_bak', 'cost', 'crca', 'crco', 'crhd', 'crhh', 'crhs', 'crtx', 'cska', 'cskb', 'csks', 'cskt', 'csku', 'csla', 'cslt', 'cssl', 'cvi_cust_link', 'dd01l', 'dd02l', 'dd02t', 'dd03l', 'dd04l', 'dd04t', 'dd07t', 'dfkkbptaxnum', 'eapl', 'eban', 'ebew', 'ebkn', 'edbast', 'edid4', 'edidc', 'edids', 'edimsgt', 'edp13', 'eina', 'eine', 
ci', 'spmeat_coco', 'spmeat_coko', 'spmeat_cokp', 'spmeat_copc', 'spmeat_copi', 'spmeat_copo', 'spmeat_ctlk', 'spmeat_ctlm', 'spmeat_ctlmc', 'spmeat_ctlmcl', 'spmeat_ctlmclk', 'spmeat_ctlmp', 'spmeat_ctlo', 'spmeat_ctlp', 'spmeat_ctlpo', 'spmeat_cuta', 'spmeat_cutap', 'spmeat_cutk', 'spmeat_cutkc', 'spmeat_cutkcl', 'spmeat_cutkclk', 'spmeat_cutkt', 'spmeat_cutp', 'spmeat_cutpc', ...

# %%
# Initialize variables to store results
all_discrepancies = []
sheets_with_discrepancies = 0
total_sheets_analyzed = 0
total_rows_analyzed = 0
total_discrepancies = 0

print("Starting analysis of all sheets...")
print("=" * 50)
# Out:
# Starting analysis of all sheets...
# ==================================================

# %%
# Analyze each sheet
for sheet_name in sheet_names:
    print(f"\nAnalyzing sheet: {sheet_name}")
    print("-" * 30)

    try:
        # Read the sheet
        df = pd.read_excel(excel_file, sheet_name=sheet_name)
        total_sheets_analyzed += 1

        print(f"Columns found: {list(df.columns)}")
        print(f"Total rows in sheet: {len(df)}")

        # Skip if the sheet is empty
        if df.empty:
            print(f"⚠️  Skipping empty sheet: {sheet_name}")
            continue

        # Check if required columns exist
        slt_col = None
        newlake_col = None

        # Look for columns that might contain the row counts (case-insensitive)
        for col in df.columns:
            col_lower = str(col).lower()
            if "sltloadedrowcount" in col_lower:
                slt_col = col
            elif "newlakeloadedrowcount" in col_lower:
                newlake_col = col

        if slt_col is None or newlake_col is None:
            print(f"⚠️  Missing required columns in {sheet_name}")
            print(f"   SLTLoadedRowCount column: {slt_col}")
            print(f"   NewLakeLoadedRowCount column: {newlake_col}")
            continue

        print(f"   Using columns: '{slt_col}' and '{newlake_col}'")

        # Convert to numeric, handling any non-numeric values
        df[slt_col] = pd.to_numeric(df[slt_col], errors="coerce")
        df[newlake_col] = pd.to_numeric(df[newlake_col], errors="coerce")

        # Find rows where counts don't match
        mask = (
            (df[slt_col] != df[newlake_col])
            & (~df[slt_col].isna())
            & (~df[newlake_col].isna())
        )
        discrepancies = df[mask].copy()

        if len(discrepancies) > 0:
            sheets_with_discrepancies += 1
            total_discrepancies += len(discrepancies)

            print(f"❌ Found {len(discrepancies)} discrepancies in {sheet_name}")

            # Add sheet name to each discrepancy row
            discrepancies["SheetName"] = sheet_name
            discrepancies["SLTCount"] = discrepancies[slt_col]
            discrepancies["NewLakeCount"] = discrepancies[newlake_col]
            discrepancies["Difference"] = (
                discrepancies[newlake_col] - discrepancies[slt_col]
            )

            all_discrepancies.append(discrepancies)

            # Show first few discrepancies
            print("   First few discrepancies:")
            display_cols = ["SheetName", "SLTCount", "NewLakeCount", "Difference"] + [
                col for col in df.columns if col not in [slt_col, newlake_col]
            ]
            print(discrepancies[display_cols].head().to_string(index=False))
        else:
            print(f"✅ No discrepancies found in {sheet_name}")

        total_rows_analyzed += len(df)

    except Exception as e:
        print(f"❌ Error processing sheet {sheet_name}: {e}")

print(f"\n{'='*50}")
print("Analysis Complete!")
# Out:
# Analyzing sheet: a016
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 70
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a016
#
# Analyzing sheet: a068
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 6
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a068
#
# Analyzing sheet: a551
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 63
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a551
#
# Analyzing sheet: a594
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a594
#
# Analyzing sheet: a651
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 5
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a651
#
# Analyzing sheet: a652
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a652
#
# Analyzing sheet: a653
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a653
#
# Analyzing sheet: a654
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a654
#
# Analyzing sheet: a655
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a655
#
# Analyzing sheet: a656
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a656
#
# Analyzing sheet: a717
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a717
#
# Analyzing sheet: a733
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a733
#
# Analyzing sheet: a734
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 5
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a734
#
# Analyzing sheet: a735
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 32
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a735
#
# Analyzing sheet: a736
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a736
#
# Analyzing sheet: a737
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 12
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a737
#
# Analyzing sheet: a738
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a738
#
# Analyzing sheet: a748
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 17
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a748
#
# Analyzing sheet: a749
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 5
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a749
#
# Analyzing sheet: a753
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 10
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in a753
#
# Analyzing sheet: a757
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a757
#
# Analyzing sheet: a762
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: a762
#
# Analyzing sheet: acdoca
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in acdoca
#
# Analyzing sheet: acdoca_m_extract
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2001
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in acdoca_m_extract
#
# Analyzing sheet: acdocp
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in acdocp
#
# Analyzing sheet: adr12
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 14
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adr12
#
# Analyzing sheet: adr2
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 335
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adr2
#
# Analyzing sheet: adr3
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 266
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adr3
#
# Analyzing sheet: adr6
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adr6
#
# Analyzing sheet: adrc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 347
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adrc
#
# Analyzing sheet: adrct
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 3
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adrct
#
# Analyzing sheet: adrp
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 177
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adrp
#
# Analyzing sheet: adrt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 153
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in adrt
#
# Analyzing sheet: afih
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afih
#
# Analyzing sheet: afko
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2001
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afko
#
# Analyzing sheet: afpo
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afpo
#
# Analyzing sheet: afru
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afru
#
# Analyzing sheet: afvc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afvc
#
# Analyzing sheet: afvu
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afvu
#
# Analyzing sheet: afvv
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in afvv
#
# Analyzing sheet: agr_1251
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: agr_1251
#
# Analyzing sheet: agr_tcodes
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: agr_tcodes
#
# Analyzing sheet: agr_users
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 222
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in agr_users
#
# Analyzing sheet: anka
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: anka
#
# Analyzing sheet: ankb
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ankb
#
# Analyzing sheet: ankt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ankt
#
# Analyzing sheet: anla
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 71
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in anla
#
# Analyzing sheet: anlb
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 68
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in anlb
#
# Analyzing sheet: anlc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: anlc
#
# Analyzing sheet: anlh
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 54
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in anlh
#
# Analyzing sheet: anli
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 15
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in anli
#
# Analyzing sheet: anlz
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 60
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in anlz
#
# Analyzing sheet: auak
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 620
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in auak
#
# Analyzing sheet: auas
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 619
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in auas
#
# Analyzing sheet: aufk
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in aufk
#
# Analyzing sheet: aufm
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in aufm
#
# Analyzing sheet: ausp
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1959
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ausp
#
# Analyzing sheet: bic_azco_d0021
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 39
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bic_azco_d0021
#
# Analyzing sheet: bic_azco_d0022
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_azco_d0022
#
# Analyzing sheet: bic_azpf_d0011
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 45
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bic_azpf_d0011
#
# Analyzing sheet: bic_azpf_d0012
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_azpf_d0012
#
# Analyzing sheet: bic_azpf_d0052
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_azpf_d0052
#
# Analyzing sheet: bic_hzglaccnt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bic_hzglaccnt
#
# Analyzing sheet: bic_pzconsview
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_pzconsview
#
# Analyzing sheet: bic_pzdatasrc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_pzdatasrc
#
# Analyzing sheet: bic_pzversion
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_pzversion
#
# Analyzing sheet: bic_szflow
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_szflow
#
# Analyzing sheet: bic_tzconsview
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_tzconsview
#
# Analyzing sheet: bic_tzdatasrc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_tzdatasrc
#
# Analyzing sheet: bic_tzpyear
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_tzpyear
#
# Analyzing sheet: bic_tzversion
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: bic_tzversion
#
# Analyzing sheet: bkpf
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bkpf
#
# Analyzing sheet: bp1010
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 50
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bp1010
#
# Analyzing sheet: bseg
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2001
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bseg
#
# Analyzing sheet: bset
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 567
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in bset
#
# Analyzing sheet: but000
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 218
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in but000
#
# Analyzing sheet: but050
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 28
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in but050
#
# Analyzing sheet: c001
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c001
#
# Analyzing sheet: c002
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c002
#
# Analyzing sheet: c003
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c003
#
# Analyzing sheet: c004
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c004
#
# Analyzing sheet: c005
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c005
#
# Analyzing sheet: c501
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: c501
#
# Analyzing sheet: cabn
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 8
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cabn
#
# Analyzing sheet: cabnt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 7
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cabnt
#
# Analyzing sheet: cawn
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 8
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cawn
#
# Analyzing sheet: cawnt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 8
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cawnt
#
# Analyzing sheet: cdhdr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2001
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cdhdr
#
# Analyzing sheet: cdpos
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2002
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cdpos
#
# Analyzing sheet: ce9tysn_h
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1003
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ce9tysn_h
#
# Analyzing sheet: ce9tysn_ic
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 989
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ce9tysn_ic
#
# Analyzing sheet: ce9tysn_iq
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ce9tysn_iq
#
# Analyzing sheet: ce9tysn_iv
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 998
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ce9tysn_iv
#
# Analyzing sheet: cepc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: cepc
#
# Analyzing sheet: cepct
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: cepct
#
# Analyzing sheet: ckis
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 109
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ckis
#
# Analyzing sheet: ckmlcr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1994
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ckmlcr
#
# Analyzing sheet: ckmlhd
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ckmlhd
#
# Analyzing sheet: ckmlkont
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmlkont
#
# Analyzing sheet: ckmllahd
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmllahd
#
# Analyzing sheet: ckmlmv001
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ckmlmv001
#
# Analyzing sheet: ckmlmv003
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 84
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ckmlmv003
#
# Analyzing sheet: ckmlmv006
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmlmv006
#
# Analyzing sheet: ckmlmv006t
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmlmv006t
#
# Analyzing sheet: ckmlmv009
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmlmv009
#
# Analyzing sheet: ckmlmv009t
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ckmlmv009t
#
# Analyzing sheet: cobk
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cobk
#
# Analyzing sheet: coepr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 67
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in coepr
#
# Analyzing sheet: cokey
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 461
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cokey
#
# Analyzing sheet: cooi
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 649
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cooi
#
# Analyzing sheet: cosl
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cosl
#
# Analyzing sheet: cosp_bak
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cosp_bak
#
# Analyzing sheet: cosr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 67
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cosr
#
# Analyzing sheet: coss_bak
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in coss_bak
#
# Analyzing sheet: cost
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 6
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cost
#
# Analyzing sheet: crca
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 8
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crca
#
# Analyzing sheet: crco
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 6
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crco
#
# Analyzing sheet: crhd
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 18
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crhd
#
# Analyzing sheet: crhh
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crhh
#
# Analyzing sheet: crhs
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 3
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crhs
#
# Analyzing sheet: crtx
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 7
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in crtx
#
# Analyzing sheet: cska
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: cska
#
# Analyzing sheet: cskb
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: cskb
#
# Analyzing sheet: csks
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 7
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in csks
#
# Analyzing sheet: cskt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 7
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cskt
#
# Analyzing sheet: csku
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: csku
#
# Analyzing sheet: csla
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: csla
#
# Analyzing sheet: cslt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: cslt
#
# Analyzing sheet: cssl
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 3
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cssl
#
# Analyzing sheet: cvi_cust_link
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 85
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in cvi_cust_link
#
# Analyzing sheet: dd01l
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: dd01l
#
# Analyzing sheet: dd02l
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 9
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in dd02l
#
# Analyzing sheet: dd02t
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 9
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in dd02t
#
# Analyzing sheet: dd03l
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 9
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in dd03l
#
# Analyzing sheet: dd04l
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: dd04l
#
# Analyzing sheet: dd04t
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: dd04t
#
# Analyzing sheet: dd07t
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: dd07t
#
# Analyzing sheet: dfkkbptaxnum
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 159
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in dfkkbptaxnum
#
# Analyzing sheet: eapl
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in eapl
#
# Analyzing sheet: eban
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 661
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in eban
#
# Analyzing sheet: ebew
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1936
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ebew
#
# Analyzing sheet: ebkn
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 485
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ebkn
#
# Analyzing sheet: edbast
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: edbast
#
# Analyzing sheet: edid4
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2001
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in edid4
#
# Analyzing sheet: edidc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in edidc
#
# Analyzing sheet: edids
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in edids
#
# Analyzing sheet: edimsgt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: edimsgt
#
# Analyzing sheet: edp13
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 5
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in edp13
#
# Analyzing sheet: eina
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 382
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in eina
#
# Analyzing sheet: eine
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 382
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in eine
#
# Analyzing sheet: ekab
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 540
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ekab
#
# Analyzing sheet: ekbe
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1993
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ekbe
#
# Analyzing sheet: ekbz
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 520
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ekbz
#
# Analyzing sheet: ekes
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ekes
#
# Analyzing sheet: eket
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1998
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in eket
#
# Analyzing sheet: ekkn
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 472
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ekkn
#
# Analyzing sheet: ekko
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1938
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ...
# ✅ No discrepancies found in zgtst_usda_hdr
#
# Analyzing sheet: zinvt_alpha_plt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zinvt_alpha_plt
#
# Analyzing sheet: zinvt_campus
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zinvt_campus
#
# Analyzing sheet: zinvt_shp_lte_re
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 475
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zinvt_shp_lte_re
#
# Analyzing sheet: zinvt_usda_asgmt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zinvt_usda_asgmt
#
# Analyzing sheet: zlpc_catgdsc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zlpc_catgdsc
#
# Analyzing sheet: zlpc_causedsc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zlpc_causedsc
#
# Analyzing sheet: zlpc_dwtmrlat
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zlpc_dwtmrlat
#
# Analyzing sheet: zlpc_pdowntime
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1296
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zlpc_pdowntime
#
# Analyzing sheet: zlpct_pattain
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 337
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zlpct_pattain
#
# Analyzing sheet: zlpct_tput_tol
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zlpct_tput_tol
#
# Analyzing sheet: zlsd_edi_shipfrm
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 199
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zlsd_edi_shipfrm
#
# Analyzing sheet: zminidocxref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zminidocxref
#
# Analyzing sheet: zminoutidocxref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 667
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zminoutidocxref
#
# Analyzing sheet: zminrsrcline
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zminrsrcline
#
# Analyzing sheet: zmtdt_avg_cs_wt
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 2
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zmtdt_avg_cs_wt
#
# Analyzing sheet: zppst_dcmap
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zppst_dcmap
#
# Analyzing sheet: zptm_manufacture
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 9
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zptm_manufacture
#
# Analyzing sheet: zptmt_equi2asset
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 78
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zptmt_equi2asset
#
# Analyzing sheet: zptmt_faacmplx
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_faacmplx
#
# Analyzing sheet: zptmt_facmplxref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_facmplxref
#
# Analyzing sheet: zptmt_fuel_mastr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 6
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zptmt_fuel_mastr
#
# Analyzing sheet: zptmt_fuel_prd_r
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_fuel_prd_r
#
# Analyzing sheet: zptmt_kpiextract
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_kpiextract
#
# Analyzing sheet: zptmt_kpimstlist
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_kpimstlist
#
# Analyzing sheet: zptmt_kpiparms
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_kpiparms
#
# Analyzing sheet: zptmt_kpivermast
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zptmt_kpivermast
#
# Analyzing sheet: zqtm_reasonxref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zqtm_reasonxref
#
# Analyzing sheet: zstpt_mpoinstyp
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zstpt_mpoinstyp
#
# Analyzing sheet: zstpt_mpoinsurc
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 132
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zstpt_mpoinsurc
#
# Analyzing sheet: zstpt_mpovenadd
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 158
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zstpt_mpovenadd
#
# Analyzing sheet: zstpt_mpovenins
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zstpt_mpovenins
#
# Analyzing sheet: zstpt_mpoventyp
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: zstpt_mpoventyp
#
# Analyzing sheet: ztfit_kunnr_xref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztfit_kunnr_xref
#
# Analyzing sheet: ztfit_lifnr_xref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztfit_lifnr_xref
#
# Analyzing sheet: ztfit_matnr_xref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 10
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztfit_matnr_xref
#
# Analyzing sheet: ztfit_mfg_plnt_x
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztfit_mfg_plnt_x
#
# Analyzing sheet: ztfit_parm
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 668
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztfit_parm
#
# Analyzing sheet: ztfit_plant_cont
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 4
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztfit_plant_cont
#
# Analyzing sheet: ztfit_plant_type
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztfit_plant_type
#
# Analyzing sheet: ztfit_plants
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 4
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztfit_plants
#
# Analyzing sheet: ztfit_plt_capcty
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 4
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztfit_plt_capcty
#
# Analyzing sheet: ztfit_werks_xref
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztfit_werks_xref
#
# Analyzing sheet: ztpet_stdfrtdtl
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 7
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztpet_stdfrtdtl
#
# Analyzing sheet: ztpet_stdfrthdr
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 14
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztpet_stdfrthdr
#
# Analyzing sheet: ztpet_stdfrtmat
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 14
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztpet_stdfrtmat
#
# Analyzing sheet: ztpet_uplnchgbck
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 5
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztpet_uplnchgbck
#
# Analyzing sheet: ztwfapinvcimage
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 298
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztwfapinvcimage
#
# Analyzing sheet: ztwfattribs
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 139
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in ztwfattribs
#
# Analyzing sheet: ztwfreacodes
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 0
# ⚠️  Skipping empty sheet: ztwfreacodes
#
# Analyzing sheet: zwhs_plant_xcfg
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 1
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zwhs_plant_xcfg
#
# Analyzing sheet: zwhst_inv_recon
# ------------------------------
# Columns found: ['FromEpochMicro', 'ToEpochMicro', 'SLTLoadedRowCount', 'NewLakeLoadedRowCount', 'JobID', 'JobStartEpochMicro', 'JobEndEpochMicro']
# Total rows in sheet: 167
#    Using columns: 'SLTLoadedRowCount' and 'NewLakeLoadedRowCount'
# ✅ No discrepancies found in zwhst_inv_recon
#
# ==================================================
# Analysis Complete!

# %%
# Summary statistics # type: ignore
print("\nSUMMARY STATISTICS")
print("=" * 50)
print(f"Total sheets analyzed: {total_sheets_analyzed}")
print(f"Total rows analyzed: {total_rows_analyzed}")
print(f"Sheets with discrepancies: {sheets_with_discrepancies}")
print(f"Total discrepancies found: {total_discrepancies}")
# print(f"Processing time: {processing_time:.2f} seconds")

if total_rows_analyzed > 0:
    # print(f"Processing speed: {total_rows_analyzed/processing_time:.0f} rows/second")
    if total_discrepancies > 0:
        print(f"Discrepancy rate: {(total_discrepancies/total_rows_analyzed)*100:.2f}%")
    else:
        print("\n🎉 All row counts match perfectly!")
else:
    print("\n⚠️ No data was processed!")
# Out:
# SUMMARY STATISTICS
# ==================================================
# Total sheets analyzed: 969
# Total rows analyzed: 152799
# Sheets with discrepancies: 1
# Total discrepancies found: 101
# Discrepancy rate: 0.07%

# %%
# Display all discrepancies if any found
if all_discrepancies:
    print("\nALL DISCREPANCIES DETAILS")
    print("=" * 50)

    # Combine all discrepancies
    combined_discrepancies = pd.concat(all_discrepancies, ignore_index=True)

    # Display all discrepancies
    display_cols = ["SheetName", "SLTCount", "NewLakeCount", "Difference"] + [
        col
        for col in combined_discrepancies.columns
if total_discrepancies > 0:  # type: ignore
    report_content += f"""
### All Discrepancies Found

The following {total_discrepancies} rows have mismatched SLTLoadedRowCount and NewLakeLoadedRowCount values:

"""

    # Add each discrepancy as a table
    for i, discrepancy in enumerate(all_discrepancies):
        sheet_name = discrepancy["SheetName"].iloc[0]
        report_content += (
            f"\n#### Sheet: {sheet_name} ({len(discrepancy)} discrepancies)\n\n"
        )

        # Create a markdown table for this sheet's discrepancies
        display_cols = ["SLTCount", "NewLakeCount", "Difference"] + [
            col
            for col in discrepancy.columns
            if col not in ["SheetName", "SLTCount", "NewLakeCount", "Difference"]
        ]

        # Add table header
        report_content += "| " + " | ".join(display_cols) + " |\n"
        report_content += "| " + " | ".join(["---"] * len(display_cols)) + " |\n"

        # Add each row
        for _, row in discrepancy.iterrows():
            row_data = []
            for col in display_cols:
                value = row[col]
                if pd.isna(value):
                    row_data.append("N/A")
                else:
                    row_data.append(str(value))
            report_content += "| " + " | ".join(row_data) + " |\n"

        report_content += "\n"
else:
    report_content += (
        "\n**✅ No discrepancies found - all row counts match perfectly!**\n"
    )

report_content += (
    f"\n---\n\n*Report generated on {pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')}*"
)

# Save the report
with open("discrepancy_report.md", "w") as f:
    f.write(report_content)

print(f"\nSummary report saved to: discrepancy_report.md")
print("\nReport preview:")
print("=" * 50)
print(report_content[:1000] + "..." if len(report_content) > 1000 else report_content)
# Out:
# Summary report saved to: discrepancy_report.md
#
# Report preview:
# ==================================================
# # Excel Row Count Comparison Report
#
# ## Analysis Summary
#
# **File Analyzed:** ./output/output_csvs.xlsx
# **Analysis Date:** 2025-10-15 14:15:27
# **Processing Method:** Parallel analysis using 8 processes
#
# ### Statistics
# - Total sheets analyzed: 969
# - Total rows analyzed: 152799
# - Sheets with discrepancies: 1
# - Total discrepancies found: 101
#
# ### Discrepancy Rate
# 0.07% of rows have mismatched counts
#
# ## Detailed Results
#
#
# ### All Discrepancies Found
#
# The following 101 rows have mismatched SLTLoadedRowCount and NewLakeLoadedRowCount values:
#
#
# #### Sheet: kna1 (101 discrepancies)
#
# | SLTCount | NewLakeCount | Difference | FromEpochMicro | ToEpochMicro | SLTLoadedRowCount | NewLakeLoadedRowCount | JobID | JobStartEpochMicro | JobEndEpochMicro |
# | --- | --- | --- | --- | --- | --- | --- | --- | --- | --- |
# | 0 | 1 | 1 | 2025-10-02 21:19:44 | 2025-10-02 21:24:58 | 0 | 1 | e5bc45d7-0934-4687-9b63-1c7f19b10b08 | 2025-10-02 21:30:35 | 2025-10-02 21:30:39 |
# | 0 | 1 | 1 | 2025-10-02 21:14:00 | 20...

# %%
# Performance analysis and optimization notes # type: ignore
print("\nPERFORMANCE ANALYSIS")
print("=" * 50)
print(f"CPU cores available: {mp.cpu_count()}")
print(f"Processes used: {num_processes}")
print(f"Total processing time: {processing_time:.2f} seconds")

if total_sheets_analyzed > 0:
    avg_time_per_sheet = processing_time / total_sheets_analyzed
    print(f"Average time per sheet: {avg_time_per_sheet:.2f} seconds")

    # Estimate sequential processing time
    estimated_sequential_time = avg_time_per_sheet * total_sheets_analyzed
    speedup = estimated_sequential_time / processing_time if processing_time > 0 else 1
    print(f"Estimated sequential time: {estimated_sequential_time:.2f} seconds")
    print(f"Speedup factor: {speedup:.1f}x faster with parallel processing")

print(f"\nMemory usage optimization:")
print(f"- Each process handles one sheet at a time")
print(f"- Results are collected and processed after parallel execution")
print(f"- Large DataFrames are processed in separate processes to avoid memory issues")
# Out:
# PERFORMANCE ANALYSIS
# ==================================================
# CPU cores available: 10
# Processes used: 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 6
#       4 print(f"CPU cores available: {mp.cpu_count()}")
#       5 print(f"Processes used: {num_processes}")
# ----> 6 print(f"Total processing time: {processing_time:.2f} seconds")
#       8 if total_sheets_analyzed > 0:
#       9     avg_time_per_sheet = processing_time / total_sheets_analyzed
#
# NameError: name 'processing_time' is not defined

# %%
# Alternative: Simple parallel processing using concurrent.futures (more reliable in Jupyter) # type: ignore
from concurrent.futures import ProcessPoolExecutor, as_completed
import sys


def run_parallel_analysis_alternative():
    """Alternative parallel processing using concurrent.futures"""
    print(f"\nTrying alternative parallel processing method...")
    print(f"Processing {len(sheet_names)} sheets using {num_processes} processes...")

    results = []

    try:
        with ProcessPoolExecutor(max_workers=num_processes) as executor:
            # Submit all tasks
            future_to_sheet = {
                executor.submit(analyze_sheet, sheet_name, excel_file): sheet_name
                for sheet_name in sheet_names
            }

            # Collect results as they complete
            for i, future in enumerate(as_completed(future_to_sheet)):
                sheet_name = future_to_sheet[future]
                try:
                    result = future.result()
                    results.append(result)
                    if i % 50 == 0:  # Progress indicator
                        print(f"Completed {i+1}/{len(sheet_names)} sheets")
                except Exception as e:
                    print(f"Error processing {sheet_name}: {e}")
                    # Add error result
                    results.append(
                        {
                            "sheet_name": sheet_name,
                            "success": False,
                            "error": str(e),
                            "columns": [],
                            "total_rows": 0,
                            "discrepancies": pd.DataFrame(),
                            "slt_col": None,
                            "newlake_col": None,
                        }
                    )

        print("✅ Alternative parallel processing completed successfully")
        return results

    except Exception as e:
        print(f"⚠️ Alternative parallel processing also failed: {e}")
        return None


# Uncomment the line below to try the alternative method if the main one fails
# results = run_parallel_analysis_alternative()

# %%
# Test multiprocessing setup with a small sample # type: ignore
def test_multiprocessing():
    """Test if multiprocessing works with a small sample"""
    print("Testing multiprocessing setup...")

    # Test with just the first 3 sheets
    test_sheets = sheet_names[:3] if len(sheet_names) >= 3 else sheet_names

    try:
        analyze_func = partial(analyze_sheet, excel_file=excel_file)
        with mp.Pool(processes=min(2, num_processes)) as pool:
            test_results = pool.map(analyze_func, test_sheets)

        print(
            f"✅ Multiprocessing test successful with {len(test_results)} test sheets"
        )
        return True

    except Exception as e:
        print(f"❌ Multiprocessing test failed: {e}")
        return False


# Run the test
multiprocessing_works = test_multiprocessing()

if not multiprocessing_works:
    print("\n⚠️ Multiprocessing is not working properly.")
    print("The notebook will use sequential processing instead.")
    print("This may be slower but will still complete the analysis.")
